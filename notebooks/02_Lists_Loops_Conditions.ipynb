# %% [markdown]
# <a href="https://colab.research.google.com/github/rsgis2025vedika-dev/python-basics/blob/main/notebooks/02_Lists_Loops_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 2 – Lists, Loops, and Conditions (Google Colab Edition)
# This notebook covers Python lists, loops, and conditional statements.

# %% [markdown]
# ## 1. Lists in Python
# ### 🔶 Task 1.1 – Create a weekly SST list

# %%
# TODO: Create your SST list and print first, last, and length.
sst =  [28.1, 28.3, 28.0, 27.9, 28.4, 28.6, 28.5]
sst_first = 28.1
sst_last = 28.5
sst_length = 7

print("First value:",sst_first )
print("Last value:",sst_last )
print("Length of list:",sst_length )
# Out:
# First value: 28.1
# Last value: 28.5
# Length of list: 7

# %% [markdown]
# ## 2. Loops (for-loops)
# ### 🔶 Task 2.1 – Print each value

# %%
# TODO: Print each SST value with day number.
for i in range(len(sst)):
    temp = sst[i]
    print(f"Day {i + 1}: {temp}")
# Out:
# Day 1: 28.1
# Day 2: 28.3
# Day 3: 28.0
# Day 4: 27.9
# Day 5: 28.4
# Day 6: 28.6
# Day 7: 28.5
# vedika

# %% [markdown]
# ## 3. Computing Mean using Loop
# ### 🔶 Task 3.1 – Compute mean SST manually

# %%
total = 0

for temp in sst:
    pass

mean_sst = total / len(sst)
print("Mean SST (loop):", mean_sst)
print("Mean SST (built-in):", sum(sst)/len(sst))
# Out:
# Mean SST (loop): 0.0
# Mean SST (built-in): 28.25714285714286

# %% [markdown]
# ## 4. Conditions: HOT or NORMAL days
# ### 🔶 Task 4.1 – Classify SST days

# %%
threshold = 28.5

for i in range(len(sst)):
    temp = sst[i]
    day = i + 1
    # TODO: write if condition here
    if temp > threshold:
      print(f"HOT Day {day}, SST: {temp}")
    else:
      print(f"NORMAL Day {day}, SST: {temp}")
# Out:
# NORMAL Day 1, SST: 28.1
# NORMAL Day 2, SST: 28.3
# NORMAL Day 3, SST: 28.0
# NORMAL Day 4, SST: 27.9
# NORMAL Day 5, SST: 28.4
# HOT Day 6, SST: 28.6
# NORMAL Day 7, SST: 28.5

# %% [markdown]
# ## 5. Filtering SST values
# ### 🔶 Task 5.1 – Create HOT and NORMAL SST lists

# %%
sst = [28.1, 28.3, 28.0, 27.9, 28.4, 28.6, 28.5]
hot_sst = []
normal_sst = []
threshold = 28.5

for i in range(len(sst)):
    temp = sst[i]
    if temp > threshold:
        hot_sst.append(temp)
    if temp < threshold:
        normal_sst.append(temp)

print("Hot SST values:", hot_sst)
print("Normal SST values:", normal_sst)
# Out:
# Hot SST values: [28.6]
# Normal SST values: [28.1, 28.3, 28.0, 27.9, 28.4]

# %% [markdown]
# ## 6. Mini Task – Rainfall classification
# ### 🔶 Task 6.1 – Classify rainfall intensity

# %%
rain = [0.0, 12.5, 34.0, 2.0, 0.0, 55.1, 8.4]

no_rain = 0.0
light = 0.0
moderate = 0.0
heavy = 0.0

for r in rain:
    if r == 0.0:
        no_rain += 1
    elif r < 10.0:
        light += 1
    elif r < 30.0:
        moderate += 1
    else:
        heavy += 1

print("No rain days:", no_rain)
print("Light rain days:", light)
print("Moderate rain days:", moderate)
print("Heavy rain days:", heavy)
# Out:
# No rain days: 2.0
# Light rain days: 2.0
# Moderate rain days: 1.0
# Heavy rain days: 2.0

# %% [markdown]
# ## 7. Reflection
# Write 3–5 sentence answers to the reflection questions here.
